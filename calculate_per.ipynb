# %%
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

# %%
_target_path = "workspace/data/LibriSpeech/train-dev-test-clean/preprocessed/precompute_pca512_cls128_mean_pooled/valid.phn"
_pred_path = "workspace/results/LibriSpeech/train-dev-test-clean/bs128_libri90_wiki103_g2p/0//valid.txt"

# %%
with open(_target_path,"r") as f:
    target_data = f.readlines()
    
with open(_pred_path,"r") as f:
    pred_data = f.readlines()
per = []
for t,p in zip(target_data,pred_data):
    print(t.split(),p.split())
    #s()
    dist = levenshteinDistance(t.split(),p.split())
    print(dist,len(t.split()))
    per.append(dist/len(t.split()))

print("PER:",sum(per)/len(per))
# Out:
# ['N', 'AO', 'R', 'W', 'AA', 'Z', 'DH', 'IH', 'S', 'IH', 'G', 'Z', 'AE', 'K', 'T', 'L', 'IY', 'DH', 'AH', 'SH', 'EY', 'P', 'DH', 'AH', 'TH', 'IH', 'NG', 'T', 'UH', 'K', 'T', 'UW', 'DH', 'AH', 'K', 'AA', 'N', 'SH', 'AH', 'S', 'N', 'AH', 'S', 'AH', 'V', 'DH', 'AH', 'M', 'Y', 'UW', 'Z', 'IH', 'SH', 'AH', 'N'] ['L', 'D', 'N', 'AO', 'W', 'AA', 'Z', 'IH', 'S', 'IH', 'K', 'S', 'AE', 'K', 'L', 'IY', 'V', 'SH', 'EY', 'P', 'T', 'AH', 'D', 'IH', 'NG', 'K', 'T', 'IH', 'K', 'T', 'UW', 'V', 'AH', 'K', 'AA', 'N', 'SH', 'AH', 'S', 'T', 'N', 'AH', 'S', 'AH', 'V', 'AH', 'M', 'Y', 'UW', 'Z', 'IH', 'SH', 'AH', 'N']
# 16 55
# ['HH', 'IY', 'W', 'AA', 'Z', 'IH', 'N', 'AH', 'M', 'UW', 'D', 'F', 'AO', 'R', 'M', 'Y', 'UW', 'Z', 'IH', 'K', 'W', 'AA', 'Z', 'HH', 'IY', 'N', 'AA', 'T'] ['D', 'W', 'AA', 'IH', 'N', 'AH', 'M', 'UW', 'D', 'F', 'AO', 'M', 'Y', 'UW', 'Z', 'IH', 'K', 'W', 'AA', 'Z', 'HH', 'IY', 'N', 'AA', 'T']
# 4 28
# ...
